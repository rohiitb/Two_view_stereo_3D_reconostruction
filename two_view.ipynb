# %% [markdown]
# # CIS580 Final Homework

# %% [markdown]
# ## 1. Two View Stereo

# %%
# !conda install -c conda-forge transforms3d --y
# !pip install pyrender
# !pip install trimesh

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import cv2

EPS = 1e-8

from utils import viz_camera_poses

# %% [markdown]
# ### 1.0 Load Data
#
# Note: you can uncomment the `viz_camera_poses([view_i, view_j])` to interactively understand the camera configuration, you will get some coordinates colored R-X, G-Y, B-Z. Press `i` in the interactive pyrender window to show the world coordinate.
#
# You will find that in the world frame, for each camera, X+ direction is vertically upward, the Y+ direction towards the right, and the Z+ forward.
#
# You will get views that are lying horizontally. In each image, the left-up corner has integer pixel coordinate [u,v] = [0,0]. The first index/row index of the image corresponds to Y or v, and the second index/col index of the image corresponds to X or u.

# %%
# Load data
from dataloader import load_middlebury_data
DATA = load_middlebury_data("data/templeRing")
# reference: https://vision.middlebury.edu/mview/

view_i, view_j = DATA[0], DATA[3]
# viz_camera_poses([view_i, view_j])

plt.subplot(1, 2, 1)
plt.title("Sample: left view (reference)")
plt.imshow(view_i["rgb"])
plt.subplot(1, 2, 2)
plt.title("Sample: right view")
plt.imshow(view_j["rgb"])
plt.show()
# Out:
# Loading data/templeRing
# 47it [00:01, 32.45it/s]

# %% [markdown]
# ### 1.1 Rectify two views
#
# <!-- Complete the function `compute_right2left_transformation` and `compute_rectification_R`; we have implemented the calibration `rectify_2view`  for you after you get the `R_irect` -->

# %%
# !pip install open3d
# Out:
# Requirement already satisfied: open3d in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (0.15.1)
# Requirement already satisfied: jupyterlab==3.*,>=3.0.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (3.2.9)
# Requirement already satisfied: wheel>=0.36.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (0.37.1)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (1.19.5)
# Requirement already satisfied: jupyter-packaging~=0.10 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (0.10.6)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (58.0.4)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (2.12.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from open3d) (7.7.0)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (2.10.3)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (1.13.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (21.3)
# Requirement already satisfied: ipython in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (7.16.3)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (6.1)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (0.3.5)
# Requirement already satisfied: jinja2>=2.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (3.0.3)
# Requirement already satisfied: jupyter-core in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (4.9.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (4.3.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (5.5.6)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipywidgets>=7.6.0->open3d) (3.6.0)
# Requirement already satisfied: jupyter-client in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (7.1.2)
# Requirement already satisfied: jedi<=0.17.2,>=0.10 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.17.2)
# Requirement already satisfied: backcall in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (3.0.29)
# Requirement already satisfied: pickleshare in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.7.5)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.4.4)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (4.4.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jedi<=0.17.2,>=0.10->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jinja2>=2.1->jupyterlab==3.*,>=3.0.0->open3d) (2.0.1)
# Requirement already satisfied: deprecation in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-packaging~=0.10->open3d) (2.1.0)
# Requirement already satisfied: tomlkit in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-packaging~=0.10->open3d) (0.11.0)
# Requirement already satisfied: websocket-client in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.3.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (3.6.1)
# Requirement already satisfied: Send2Trash in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.12.1)
# Requirement already satisfied: argon2-cffi in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (23.1.0)
# Requirement already satisfied: prometheus-client in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.14.1)
# Requirement already satisfied: dataclasses in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.8)
# Requirement already satisfied: contextvars in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (2.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (3.3)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (1.5.5)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0->open3d) (304)
# Requirement already satisfied: babel in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (2.10.1)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (3.2.0)
# Requirement already satisfied: json5 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (0.9.8)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (2.27.1)
# Requirement already satisfied: importlib-metadata in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (4.8.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (21.4.0)
# Requirement already satisfied: notebook<7 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbclassic~=0.2->jupyterlab==3.*,>=3.0.0->open3d) (6.4.10)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.5.9)
# Requirement already satisfied: testpath in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.6.0)
# Requirement already satisfied: defusedxml in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.7.1)
# Requirement already satisfied: bleach in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.10)
# Requirement already satisfied: wcwidth in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.2.5)
# Requirement already satisfied: immutables>=0.9 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from contextvars->anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.18)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.1.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (2.21)
# Requirement already satisfied: pytz>=2015.7 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from babel->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (2022.1)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab==3.*,>=3.0.0->open3d) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from importlib-metadata->jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from packaging->jupyterlab==3.*,>=3.0.0->open3d) (3.0.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\skymul\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab==3.*,>=3.0.0->open3d) (2021.5.30)

# %%
from two_view_stereo import (
    rectify_2view,
    compute_rectification_R,
    compute_right2left_transformation,
)

R_wi, T_wi = view_i["R"], view_i["T"][:, None]  # p_i = R_wi @ p_w + T_wi
R_wj, T_wj = view_j["R"], view_j["T"][:, None]  # p_j = R_wj @ p_w + T_wj

R_ji, T_ji, B = compute_right2left_transformation(R_wi, T_wi, R_wj, T_wj)
assert T_ji[1, 0] > 0, "here we assume view i should be on the left, not on the right"

R_irect = compute_rectification_R(T_ji)

rgb_i_rect, rgb_j_rect, K_i_corr, K_j_corr = rectify_2view(
    view_i["rgb"],
    view_j["rgb"],
    R_irect,
    R_irect @ R_ji,
    view_i["K"],
    view_j["K"],
    u_padding=20,
    v_padding=20,
)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
plt.subplot(2, 2, 1)
plt.title("input view i")
plt.imshow(cv2.rotate(view_i["rgb"], cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 2)
plt.title("input view j")
plt.imshow(cv2.rotate(view_j["rgb"], cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 3)
plt.title("rect view i")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 4)
plt.title("rect view j")
plt.imshow(cv2.rotate(rgb_j_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Compute the disparity

# %%
from two_view_stereo import image2patch, ssd_kernel

assert K_i_corr[1, 1] == K_j_corr[1, 1], "This hw assumes the same focal Y length"
assert (K_i_corr[0] == K_j_corr[0]).all(), "This hw assumes the same K on X dim"
assert (
    rgb_i_rect.shape == rgb_j_rect.shape
), "This hw makes rectified two views to have the same shape"

h, w = rgb_i_rect.shape[:2]

d0 = K_j_corr[1, 2] - K_i_corr[1, 2]

patches_i = image2patch(rgb_i_rect.astype(float) / 255.0, 3)  # [h,w,k*k,3]
patches_j = image2patch(rgb_j_rect.astype(float) / 255.0, 3)  # [h,w,k*k,3]

vi_idx, vj_idx = np.arange(h), np.arange(h)
disp_candidates = vi_idx[:, None] - vj_idx[None, :] + d0
valid_disp_mask = disp_candidates > 0.0

# as an example
u = 400

buf_i, buf_j = patches_i[:, u], patches_j[:, u]
value = ssd_kernel(buf_i, buf_j)  # each row is one pix from left, col is the disparity
# Students, why we compute this `_upper` ?
_upper = value.max() + 1.0
value[~valid_disp_mask] = _upper

# %%
plt.subplot(1,2,1)
# Viz the  disparity-cost of u=500, v=200 on left view
v = 200
plt.title("Cost-Disparity of one left pixel")
plt.xlabel("Disparity")
plt.ylabel("Cost")
plt.plot(disp_candidates[v], value[v])
plt.subplot(1,2,2)
plt.title("The cost map of one left horizon col")
plt.xlabel("Disparity")
plt.ylabel("left pixel coordinates  v_L")
plt.imshow(value)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's do the Left-Right consistency: in above right figure, the vertical axis is the left pixel coordinates and the horizontal axis is the right pixel (disparity).
#
# When we find the minimal cost right view pixel for our reference pixel (e.g. find the minimum of the left figure), we only check the best matched right pixel patch, which corresponds to finding the minimum along the horizontal axis of the right cost map.
#
# However, the matching from the left to the right and from the right to the left should be consistent.
# So we should also check the minimum of the vertical axis and see whether this two minimum agree with each other, below is an example

# %%
# example for the pixel (u=500,v=300) from the left view
v = 300
best_matched_right_pixel = value[v].argmin()
best_matched_left_pixel = value[:,best_matched_right_pixel].argmin()
print(v, best_matched_left_pixel)
consistent_flag = best_matched_left_pixel == v
print(consistent_flag)

# example for the pixel (u=500,v=380) from the left view
v = 380
best_matched_right_pixel = value[v].argmin()
best_matched_left_pixel = value[:,best_matched_right_pixel].argmin()
print(v, best_matched_left_pixel)
consistent_flag = best_matched_left_pixel == v
print(consistent_flag)
# Out:
# 300 300
# True
# 380 113
# False

# %% [markdown]
# Based on above example, iterate over all u, complete the function `compute_disparity_map`.
#
# Tips: for vectorized operation, you may use `take_along_axis` with `argmin` from numpy, please check the documentation from numpy to understand how to use the function

# %%
from two_view_stereo import compute_disparity_map

disp_map, consistency_mask = compute_disparity_map(
    rgb_i_rect, rgb_j_rect, d0=K_j_corr[1, 2] - K_i_corr[1, 2], k_size=5
)

# %%
plt.imshow(cv2.rotate(consistency_mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.title("L-R consistency check mask")
plt.show()

# %% [markdown]
# ### 1.3 Compute the depth map and point cloud reconstruction

# %%
from two_view_stereo import compute_dep_and_pcl

# * 3. compute depth map and filter them
dep_map, xyz_cam = compute_dep_and_pcl(disp_map, B, K_i_corr)

plt.subplot(1, 3, 1)
plt.title("rgb")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(1, 3, 2)
plt.title("raw disparity")
plt.imshow(cv2.rotate(disp_map, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.subplot(1, 3, 3)
plt.title("raw depth")
plt.imshow(cv2.rotate(dep_map, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4 Postprocessing and visualization

# %%
from two_view_stereo import postprocess

mask, pcl_world, pcl_cam, pcl_color = postprocess(
    dep_map,
    rgb_i_rect,
    xyz_cam,
    R_wc=R_irect @ R_wi,
    T_wc=R_irect @ T_wi,
    consistency_mask=consistency_mask,
    z_near=0.5,
    z_far=0.6,
)

mask = (mask > 0).astype(np.float)

plt.subplot(1, 3, 1)
plt.title("rgb")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(1, 3, 2)
plt.title("postproc disparity")
plt.imshow(cv2.rotate(disp_map * mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.subplot(1, 3, 3)
plt.title("postproc depth")
plt.imshow(cv2.rotate(dep_map * mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.show()

# %%
# !pip install k3d
# !jupyter nbextension install --py --user k3d
# !jupyter nbextension enable --py --user k3d
# Out:
# Installing C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static -> k3d
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\extension.js
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\extension.js -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\extension.js
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\fflate.js
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\fflate.js -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\fflate.js
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\headless.html
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\headless.html -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\headless.html
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\index.js -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js.LICENSE.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\index.js.LICENSE.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js.LICENSE.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js.map
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\index.js.map -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\index.js.map
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\require.js
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\require.js -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\require.js
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\require.js.LICENSE.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\require.js.LICENSE.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\require.js.LICENSE.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_inline.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\snapshot_inline.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_inline.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_online.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\snapshot_online.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_online.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_standalone.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\snapshot_standalone.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\snapshot_standalone.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\standalone.js -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js.LICENSE.txt
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\standalone.js.LICENSE.txt -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js.LICENSE.txt
# Out of date: C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js.map
# Copying: C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\k3d\static\standalone.js.map -> C:\Users\Dell\AppData\Roaming\jupyter\nbextensions\k3d\standalone.js.map
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable k3d --user --py
#
# Enabling notebook extension k3d/extension...
#       - Validating: ok

# %%
import k3d
import numpy as np

def viz_3d_embedded(pcl, color):
    plot = k3d.plot(camera_auto_fit=True)
    color = color.astype(np.uint8)
    color32 = (color[:, 0] * 256**2 + color[:, 1] * 256**1 + color[:, 2] * 256**0).astype(
        np.uint32
    )
    plot += k3d.points(pcl.astype(float), color32, point_size=0.001, shader="flat")
    plot.display()

# %% [markdown]
# #### SSD Two view reconstruction results

# %%
viz_3d_embedded(pcl_world, pcl_color.astype(np.uint8))
# Out:
# C:\Users\Dell\anaconda3\envs\skymul\lib\site-packages\traittypes\traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# Output()

# %% [markdown]
# #### SAD Two view reconstruction results
# <!-- ### 1.5 Put things together and try different Similarity -->

# %%
from two_view_stereo import two_view ,sad_kernel

pcl_sad, pcl_color_sad, disp_map_sad, dep_map_sad = two_view(DATA[0], DATA[2], 5, sad_kernel)
viz_3d_embedded(pcl_sad, pcl_color_sad.astype(np.uint8))
# Out:
# Output()

# %% [markdown]
# #### ZNCC Two view reconstruction results

# %%
from two_view_stereo import two_view, zncc_kernel

pcl_zncc, pcl_color_zncc, disp_map_zncc, dep_map_zncc = two_view(DATA[0], DATA[2], 5, zncc_kernel)
viz_3d_embedded(pcl_zncc, pcl_color_zncc.astype(np.uint8))
# Out:
# Output()

# %% [markdown]
# ### 1.5 Aggregation

# %%
from two_view_stereo import two_view, ssd_kernel, sad_kernel, zncc_kernel

pcl_list, pcl_color_list, disp_map_list, dep_map_list = [], [], [], []
pairs = [(0, 2), (2, 4), (5, 7), (8, 10), (13, 15), (16, 18), (19, 21), (22, 24), (25, 27)]
# for i in range(13, 28, 3):
for pair in pairs:
    i,j = pair
    _pcl, _pcl_color, _disp_map, _dep_map = two_view(DATA[i], DATA[j], 5, sad_kernel)
    pcl_list.append(_pcl)
    pcl_color_list.append(_pcl_color)
    disp_map_list.append(_disp_map)
    dep_map_list.append(_dep_map)

# %%
plot = k3d.plot(camera_auto_fit=True)
for pcl, color in zip(pcl_list, pcl_color_list):
    color = color.astype(np.uint8)
    color32 = (color[:, 0] * 256**2 + color[:, 1] * 256**1 + color[:, 2] * 256**0).astype(
        np.uint32
    )
    plot += k3d.points(pcl.astype(float), color32, point_size=0.001, shader="flat")
plot.display()
# Out:
# Output()

# %%
plot.display()
# Out:
# Output()
